# %%
import corr_func

# %%
from corr_func import load_cat, angular_corrfunc

# %%
data_stack = load_cat()
# Out:
# Runtime of 0.325647 seconds after 0 pixels
# Runtime of 9.619091 seconds after 20 pixels
# Runtime of 18.931214 seconds after 40 pixels
# Runtime of 28.781365 seconds after 60 pixels
# Runtime of 36.891430 seconds after 80 pixels
# Runtime of 46.674746 seconds after 100 pixels
# Runtime of 58.591405 seconds after 120 pixels
# Runtime of 65.300946 seconds after 140 pixels
# Runtime of 72.791610 seconds after 160 pixels
# Runtime of 83.218344 seconds after 180 pixels
# Runtime of 97.139962 seconds after 200 pixels
# Runtime of 107.989511 seconds after 220 pixels
# Runtime of 114.879412 seconds after 240 pixels
# Runtime of 127.001935 seconds after 260 pixels
# Runtime of 139.902483 seconds after 280 pixels
# Runtime of 158.448925 seconds after 300 pixels
# Runtime of 172.359959 seconds after 320 pixels
# Runtime of 186.118551 seconds after 340 pixels
# Runtime of 197.029316 seconds after 360 pixels
# Runtime of 205.756671 seconds after 380 pixels
# ...

# %%
data_stack
# Out:
# <Table length=12586850>
#         RA                DEC              TARGETID     ... MWS_TARGET PHOTSYS
#      float64            float64             int64       ...   int64     bytes1
# ------------------ ------------------ ----------------- ... ---------- -------
#  39.87345241480437  4.665933584901227 39627900093202905 ...          0       S
# 39.877053486508814  4.711238350826682 39627900093203017 ...          0       S
#  39.87915609182511  4.770786080678859 39627900093203092 ...          0       S
#   39.8820675774046   4.81261018424266 39627900093203195 ...          0       S
#   39.8906900429301  4.853959519139267 39627900093203471 ...          0       S
#  39.89212755501432  4.831044142844941 39627900093203516 ...          0       S
#  39.89672633565589  4.833354165330929 39627900093203673 ...          0       S
#  39.90121357739571  4.672729345915309 39627900093203812 ...          0       S
#  39.90993597426195  4.638922607666945 39627900093204074 ...          0       S
# ...

# %%
angular_corrfunc(data_stack,150,155,0,5,2)
# Out:
# /global/homes/l/lbigwood/.local/lib/python3.8/site-packages/Corrfunc/utils.py:918: UserWarning: One or more input array has non-native endianness!  A copy will be made with the correct endianness.
#   warnings.warn("One or more input array has non-native endianness!  A copy will"\
